# %% [markdown]
# # Wine Classification

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split as TTS
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
wine=pd.read_csv('wine.csv')

# %% [markdown]
# ## Overview of wine dataset and its division into training, testing datasets (scaled):

# %%
wine.shape
# Out:
# (178, 14)

# %%
wine
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
wine.isnull().sum()
# Out:
# Class                           0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
wine.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
Train,Test=TTS(wine,test_size=0.25,random_state=4)

# %%
Train
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 5        1    14.20        1.76  2.45               15.2        112
# 101      2    12.60        1.34  1.90               18.5         88
# 141      3    13.36        2.56  2.35               20.0         89
# 25       1    13.05        2.05  3.22               25.0        124
# 148      3    13.32        3.24  2.38               21.5         92
# ..     ...      ...         ...   ...                ...        ...
# 87       2    11.65        1.67  2.62               26.0         88
# 104      2    12.51        1.73  1.98               20.5         85
# 129      2    12.04        4.30  2.38               22.0         80
# 174      3    13.40        3.91  2.48               23.0        102
# 122      2    12.42        4.43  2.73               26.5        102
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 5             3.27        3.39                  0.34             1.97
# ...

# %%
Test
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 163      3    12.96        3.45  2.35               18.5        106
# 142      3    13.52        3.17  2.72               23.5         97
# 14       1    14.38        1.87  2.38               12.0        102
# 45       1    14.21        4.04  2.44               18.9        111
# 81       2    12.72        1.81  2.20               18.8         86
# 157      3    12.45        3.03  2.64               27.0         97
# 26       1    13.39        1.77  2.62               16.1         93
# 74       2    11.96        1.09  2.30               21.0        101
# 1        1    13.20        1.78  2.14               11.2        100
# 76       2    13.03        0.90  1.71               16.0         86
# 90       2    12.08        1.83  2.32               18.5         81
# 18       1    14.19        1.59  2.48               16.5        108
# 170      3    12.20        3.03  2.32               19.0         96
# ...

# %%
Train.shape
# Out:
# (133, 14)

# %%
Test.shape
# Out:
# (45, 14)

# %%
X_train=Train.drop(['Class'],axis=1)

# %%
X_train.head()
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 5      14.20        1.76  2.45               15.2        112           3.27
# 101    12.60        1.34  1.90               18.5         88           1.45
# 141    13.36        2.56  2.35               20.0         89           1.40
# 25     13.05        2.05  3.22               25.0        124           2.63
# 148    13.32        3.24  2.38               21.5         92           1.93
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 5          3.39                  0.34             1.97             6.75  1.05
# 101        1.36                  0.29             1.35             2.45  1.04
# 141        0.50                  0.37             0.64             5.60  0.70
# 25         2.68                  0.47             1.92             3.58  1.13
# 148        0.76                  0.45             1.25             8.42  0.55
#
# ...

# %%
Y_train=Train['Class']

# %%
Y_train.head()
# Out:
# 5      1
# 101    2
# 141    3
# 25     1
# 148    3
# Name: Class, dtype: int64

# %%
X_test=Test.drop(['Class'],axis=1)

# %%
X_test.head()
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 163    12.96        3.45  2.35               18.5        106           1.39
# 142    13.52        3.17  2.72               23.5         97           1.55
# 14     14.38        1.87  2.38               12.0        102           3.30
# 45     14.21        4.04  2.44               18.9        111           2.85
# 81     12.72        1.81  2.20               18.8         86           2.20
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 163        0.70                  0.40             0.94             5.28  0.68
# 142        0.52                  0.50             0.55             4.35  0.89
# 14         3.64                  0.29             2.96             7.50  1.20
# 45         2.65                  0.30             1.25             5.24  0.87
# 81         2.53                  0.26             1.77             3.90  1.16
#
# ...

# %%
Y_test=Test['Class']

# %%
scaled_X = StandardScaler().fit_transform(X_train.values)

# %%
X_train_ss = pd.DataFrame(scaled_X, index=X_train.index, columns=X_train.columns)

# %%
X_train_ss.describe()
# Out:
#             Alcohol    Malic acid           Ash  Alcalinity of ash  \
# count  1.330000e+02  1.330000e+02  1.330000e+02       1.330000e+02
# mean   2.376545e-15  1.168656e-16  1.128588e-15       2.621128e-16
# std    1.003781e+00  1.003781e+00  1.003781e+00       1.003781e+00
# min   -2.404430e+00 -1.256211e+00 -3.532455e+00      -2.654497e+00
# 25%   -7.535553e-01 -6.340028e-01 -5.842564e-01      -7.212708e-01
# 50%    8.420182e-02 -4.499693e-01 -2.269469e-02      -4.757084e-02
# 75%    8.480392e-01  6.980488e-01  6.441598e-01       5.382552e-01
# max    2.277154e+00  3.046666e+00  3.030797e+00       3.028016e+00
#
#           Magnesium  Total phenols    Flavanoids  Nonflavanoid phenols  \
# count  1.330000e+02   1.330000e+02  1.330000e+02          1.330000e+02
# mean  -2.537653e-16   4.073600e-16 -2.671213e-16         -4.482630e-16
# std    1.003781e+00   1.003781e+00  1.003781e+00          1.003781e+00
# min   -2.083407e+00  -2.155149e+00 -1.777509e+00         -1.803919e+00
# ...

# %%
scaled_train=MinMaxScaler().fit_transform(X_train.values)
X_train_s=pd.DataFrame(scaled_train, index=X_train.index, columns=X_train.columns)

# %%
X_train_s.describe()
# Out:
#           Alcohol  Malic acid         Ash  Alcalinity of ash   Magnesium  \
# count  133.000000  133.000000  133.000000         133.000000  133.000000
# mean     0.513593    0.291947    0.538217           0.467134    0.328048
# std      0.214410    0.233281    0.152940           0.176644    0.158053
# min      0.000000    0.000000    0.000000           0.000000    0.000000
# 25%      0.352632    0.144603    0.449198           0.340206    0.195652
# 50%      0.531579    0.187373    0.534759           0.458763    0.304348
# 75%      0.694737    0.454175    0.636364           0.561856    0.413043
# max      1.000000    1.000000    1.000000           1.000000    1.000000
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count     133.000000  133.000000            133.000000       133.000000
# mean        0.463780    0.369214              0.437778         0.374019
# std         0.216010    0.208500              0.243599         0.180059
# ...

# %%
scaled_test=MinMaxScaler().fit_transform(X_test.values)
X_test_s=pd.DataFrame(scaled_test, index=X_test.index, columns=X_test.columns)

# %%
X_test_s.describe()
# Out:
#          Alcohol  Malic acid        Ash  Alcalinity of ash  Magnesium  \
# count  45.000000   45.000000  45.000000          45.000000  45.000000
# mean    0.552573    0.388229   0.650165           0.493671   0.259781
# std     0.271673    0.247138   0.237183           0.192993   0.191041
# min     0.000000    0.000000   0.000000           0.000000   0.000000
# 25%     0.312081    0.220903   0.514851           0.354430   0.126761
# 50%     0.543624    0.280285   0.663366           0.487342   0.225352
# 75%     0.778523    0.543943   0.841584           0.620253   0.323944
# max     1.000000    1.000000   1.000000           1.000000   1.000000
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count      45.000000   45.000000             45.000000        45.000000
# mean        0.449244    0.398715              0.478407         0.426095
# std         0.292352    0.294628              0.259521         0.242006
# ...

# %% [markdown]
# ## Various plots required for further analysis:

# %%
wine.Class.value_counts().plot(kind='pie') #Class distribution in original dataset

# %%
Y_train.value_counts().plot(kind='pie') #Class distribution in training dataset

# %%
Y_test.value_counts().plot(kind='pie') #Class distribution in testing dataset

# %% [markdown]
# ### In following steps, we calculated influence of each attribute to class label, in ascending order and dropped least important attributes:

# %%
att_fig, (ax) = plt.subplots(3, 3)
att_fig.suptitle('Sharing attributes(x) per class(y)')

ax[0,0].scatter(X_train_s['Flavanoids'],Y_train)
ax[0,0].set_title('Flavanoids')

ax[0,1].scatter(X_train_s['Alcohol'],Y_train)
ax[0,1].set_title('Alcohol')

ax[0,2].scatter(X_train_s['Color intensity'],Y_train)
ax[0,2].set_title('Color intensity')

ax[1,0].scatter(X_train_s['OD280/OD315 of diluted wines'],Y_train)
ax[1,0].set_title('OD280/OD315 of diluted wines')

ax[1,1].scatter(X_train_s['Hue'],Y_train)
ax[1,1].set_title('Hue')

ax[1,2].scatter(X_train_s['Proline'],Y_train)
ax[1,2].set_title('Proline')

ax[2,0].scatter(X_train_s['Malic acid'],Y_train)
ax[2,0].set_title('Malic acid')

ax[2,1].scatter(X_train_s['Alcalinity of ash'],Y_train)
ax[2,1].set_title('Alcalinity of ash');

ax[2,2].scatter(X_train['Total phenols'],Y_train)
ax[2,2].set_title('Total phenols');

#plt.savefig('att_fig')

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X_train_s,Y_train)
print(model.feature_importances_) 
feat_importances = pd.Series(model.feature_importances_, index=X_train_s.columns)
feat_importances.nlargest(13).plot(kind='barh')
#plt.savefig('comparision.png')
plt.show()
# Out:
# /home/prerak/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.12137574 0.05793906 0.03012366 0.02220212 0.04391492 0.05168184
#  0.12233764 0.0147852  0.01855592 0.1385004  0.13988627 0.05290818
#  0.18578904]

# %%
X_train_s.columns
# Out:
# Index(['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium',
#        'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %%
X_train_s1=X_train_s.drop(['Nonflavanoid phenols','Ash','Alcalinity of ash','Proanthocyanins','Malic acid'],axis=1)

# %%
X_test_s1=X_test_s.drop(['Nonflavanoid phenols','Ash','Alcalinity of ash','Proanthocyanins','Malic acid'],axis=1)

# %%
X_train_s1.columns
# Out:
# Index(['Alcohol', 'Magnesium', 'Total phenols', 'Flavanoids',
#        'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %% [markdown]
# ## SVM Classifier used:

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear')

# %%
clf.fit(X_train_s1,Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
from sklearn import metrics

# %%
Y_pred=clf.predict(X_test_s1)

# %%
print("Accuracy:{:.3f}".format(metrics.accuracy_score(Y_test, Y_pred)))
# Out:
# Accuracy:0.978

# %%
print("Precision:{:.3f}".format(metrics.precision_score(Y_test, Y_pred,average='weighted')))
# Out:
# Precision:0.979

# %%
print("Recall:{:.3f}".format(metrics.recall_score(Y_test, Y_pred,average='weighted')))
# Out:
# Recall:0.978

# %%
X_train_s1.columns
# Out:
# Index(['Alcohol', 'Magnesium', 'Total phenols', 'Flavanoids',
#        'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %%
X_test_s1.columns
# Out:
# Index(['Alcohol', 'Magnesium', 'Total phenols', 'Flavanoids',
#        'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %% [markdown]
# ## Naive Bayes Classifier used:

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train_s1,Y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred_nb = gnb.predict(X_test_s1)

# %%
print("Accuracy:{:.3f}".format(metrics.accuracy_score(Y_test, y_pred_nb)))
# Out:
# Accuracy:0.956

# %%
print("Precision:{:.3f}".format(metrics.precision_score(Y_test, y_pred_nb,average='weighted')))
# Out:
# Precision:0.961

# %%
print("Recall:{:.3f}".format(metrics.recall_score(Y_test, y_pred_nb,average='weighted')))
# Out:
# Recall:0.956

# %% [markdown]
# ## Random Forest (Decision Tree) Classifier used:

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf_r = RandomForestClassifier(max_depth=4, random_state=0)

# %%
clf_r.fit(X_train_s1,Y_train)
# Out:
# /home/prerak/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=4, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred_rf = clf_r.predict(X_test_s1)

# %%
print("Accuracy:{:.3f}".format(metrics.accuracy_score(Y_test, y_pred_rf)))
# Out:
# Accuracy:0.978

# %%
print("Precision:{:.3f}".format(metrics.precision_score(Y_test, y_pred_rf,average='weighted')))
# Out:
# Precision:0.979

# %%
print("Recall:{:.3f}".format(metrics.recall_score(Y_test, y_pred_rf,average='weighted')))
# Out:
# Recall:0.978
